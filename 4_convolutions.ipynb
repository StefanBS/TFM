# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.560595
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.431009
# Minibatch accuracy: 62.5%
# Validation accuracy: 59.2%
# Minibatch loss at step 100: 0.988308
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.5%
# Minibatch loss at step 150: 0.700620
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.4%
# Minibatch loss at step 200: 0.520006
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 250: 1.565805
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.0%
# Minibatch loss at step 300: 0.618102
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 350: 0.920684
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 400: 0.787563
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 450: 0.253094
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 500: 0.145580
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.2%
# Minibatch loss at step 550: 0.214482
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 600: 0.897307
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.1%
# Minibatch loss at step 650: 0.425577
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 700: 0.436126
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 750: 0.266125
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 800: 0.712949
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 850: 0.744897
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 900: 0.564728
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 950: 0.175380
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 1000: 0.260936
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Test accuracy: 89.3%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden = tf.nn.max_pool(hidden, [1,2,2,1], [1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.363896
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.420140
# Minibatch accuracy: 56.2%
# Validation accuracy: 59.3%
# Minibatch loss at step 100: 0.664847
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.8%
# Minibatch loss at step 150: 0.595429
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.8%
# Minibatch loss at step 200: 0.337126
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 250: 1.189646
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 300: 0.648695
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 350: 1.071218
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.4%
# Minibatch loss at step 400: 1.055472
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 450: 0.317062
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 500: 0.062212
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 550: 0.090192
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 600: 0.934196
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 650: 0.441116
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 700: 0.432417
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 750: 0.231689
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 800: 0.681679
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 850: 0.676673
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 900: 0.344923
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 950: 0.185055
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 1000: 0.155650
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.3%
# Test accuracy: 89.8%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 128
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)

  # Constants.
  beta = 0.00001
  global_step = tf.Variable(0)  # count the number of steps taken.
  dropout_keeprate = 0.7
  learning_rate = 0.75
  decay_rate = 0.98
  decay_steps = 1000
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, isTraining = False):
    if not isTraining:
        dropout_keeprate = 1
    else:
        dropout_keeprate = 0.7
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden = tf.nn.max_pool(hidden, [1,2,2,1], [1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.dropout(tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases), dropout_keeprate)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset, True)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 50001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.572437
# Minibatch accuracy: 13.3%
# Validation accuracy: 12.3%
# Minibatch loss at step 50: 1.458309
# Minibatch accuracy: 53.1%
# Validation accuracy: 67.4%
# Minibatch loss at step 100: 0.923529
# Minibatch accuracy: 69.5%
# Validation accuracy: 77.3%
# Minibatch loss at step 150: 0.898665
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.3%
# Minibatch loss at step 200: 0.904565
# Minibatch accuracy: 73.4%
# Validation accuracy: 79.8%
# Minibatch loss at step 250: 0.688951
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.9%
# Minibatch loss at step 300: 0.809922
# Minibatch accuracy: 74.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 350: 0.723675
# Minibatch accuracy: 77.3%
# Validation accuracy: 81.6%
# Minibatch loss at step 400: 0.662129
# Minibatch accuracy: 82.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 450: 0.480031
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 500: 0.813929
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.0%
# Minibatch loss at step 550: 0.478893
# Minibatch accuracy: 88.3%
# Validation accuracy: 82.8%
# Minibatch loss at step 600: 0.707043
# Minibatch accuracy: 80.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 650: 0.692199
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.5%
# Minibatch loss at step 700: 0.608955
# Minibatch accuracy: 80.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 750: 0.605922
# Minibatch accuracy: 85.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 800: 0.574975
# Minibatch accuracy: 83.6%
# Validation accuracy: 84.2%
# Minibatch loss at step 850: 0.733098
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 900: 0.549281
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.0%
# Minibatch loss at step 950: 0.688939
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 1000: 0.383139
# Minibatch accuracy: 88.3%
# Validation accuracy: 85.0%
# Minibatch loss at step 1050: 0.721516
# Minibatch accuracy: 80.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 1100: 0.520289
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 1150: 0.656081
# Minibatch accuracy: 83.6%
# Validation accuracy: 85.1%
# Minibatch loss at step 1200: 0.682801
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.5%
# Minibatch loss at step 1250: 0.420794
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 1300: 0.605776
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 1350: 0.546346
# Minibatch accuracy: 80.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 1400: 0.513776
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.9%
# Minibatch loss at step 1450: 0.534946
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.0%
# Minibatch loss at step 1500: 0.518741
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# Minibatch loss at step 1550: 0.593237
# Minibatch accuracy: 78.9%
# Validation accuracy: 86.3%
# Minibatch loss at step 1600: 0.501344
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.1%
# Minibatch loss at step 1650: 0.496786
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 1700: 0.521480
# Minibatch accuracy: 83.6%
# Validation accuracy: 86.0%
# Minibatch loss at step 1750: 0.565846
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 1800: 0.652347
# Minibatch accuracy: 79.7%
# Validation accuracy: 86.5%
# Minibatch loss at step 1850: 0.387269
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# Minibatch loss at step 1900: 0.501964
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.6%
# Minibatch loss at step 1950: 0.602198
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 2000: 0.364566
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.8%
# Minibatch loss at step 2050: 0.682041
# Minibatch accuracy: 80.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 2100: 0.501796
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.8%
# Minibatch loss at step 2150: 0.462694
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.9%
# Minibatch loss at step 2200: 0.567877
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.2%
# Minibatch loss at step 2250: 0.448185
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 2300: 0.538260
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.0%
# Minibatch loss at step 2350: 0.416583
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 2400: 0.592672
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.0%
# Minibatch loss at step 2450: 0.547101
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.2%
# Minibatch loss at step 2500: 0.450954
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.2%
# Minibatch loss at step 2550: 0.524758
# Minibatch accuracy: 82.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 2600: 0.399089
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.2%
# Minibatch loss at step 2650: 0.638225
# Minibatch accuracy: 78.9%
# Validation accuracy: 87.3%
# Minibatch loss at step 2700: 0.461033
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.4%
# Minibatch loss at step 2750: 0.412318
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.3%
# Minibatch loss at step 2800: 0.438298
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.2%
# Minibatch loss at step 2850: 0.471990
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 2900: 0.559683
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.4%
# Minibatch loss at step 2950: 0.444368
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.6%
# Minibatch loss at step 3000: 0.371612
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.6%
# Minibatch loss at step 3050: 0.490124
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.7%
# Minibatch loss at step 3100: 0.378302
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# Minibatch loss at step 3150: 0.421354
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 3200: 0.474604
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 3250: 0.510860
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 3300: 0.338650
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 3350: 0.614373
# Minibatch accuracy: 80.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 3400: 0.460801
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 3450: 0.393251
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.7%
# Minibatch loss at step 3500: 0.475634
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 3550: 0.492901
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 3600: 0.655308
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 3650: 0.354817
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.0%
# Minibatch loss at step 3700: 0.586385
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 3750: 0.454040
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.8%
# Minibatch loss at step 3800: 0.543435
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 3850: 0.407466
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.1%
# Minibatch loss at step 3900: 0.354393
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.0%
# Minibatch loss at step 3950: 0.234939
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 4000: 0.391553
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 4050: 0.515717
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.1%
# Minibatch loss at step 4100: 0.502770
# Minibatch accuracy: 83.6%
# Validation accuracy: 88.2%
# Minibatch loss at step 4150: 0.352392
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.1%
# Minibatch loss at step 4200: 0.447878
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.2%
# Minibatch loss at step 4250: 0.715657
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 4300: 0.335324
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.1%
# Minibatch loss at step 4350: 0.511001
# Minibatch accuracy: 80.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 4400: 0.381805
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 4450: 0.453312
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# Minibatch loss at step 4500: 0.539954
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.3%
# Minibatch loss at step 4550: 0.437806
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 4600: 0.436600
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.3%
# Minibatch loss at step 4650: 0.404194
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 4700: 0.390135
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.5%
# Minibatch loss at step 4750: 0.390204
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 4800: 0.399626
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.3%
# Minibatch loss at step 4850: 0.410129
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.6%
# Minibatch loss at step 4900: 0.373707
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 4950: 0.397532
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.5%
# Minibatch loss at step 5000: 0.338760
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# Minibatch loss at step 5050: 0.403187
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# Minibatch loss at step 5100: 0.304032
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.6%
# Minibatch loss at step 5150: 0.323734
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.6%
# Minibatch loss at step 5200: 0.426262
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 5250: 0.528611
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 5300: 0.377870
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 5350: 0.584863
# Minibatch accuracy: 82.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 5400: 0.470293
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.8%
# Minibatch loss at step 5450: 0.431014
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.6%
# Minibatch loss at step 5500: 0.383606
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 5550: 0.425463
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 5600: 0.335776
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 5650: 0.505149
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.6%
# Minibatch loss at step 5700: 0.310021
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# Minibatch loss at step 5750: 0.411238
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 5800: 0.347399
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 5850: 0.356200
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 5900: 0.436798
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 5950: 0.377336
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 6000: 0.446103
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 6050: 0.482188
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.0%
# Minibatch loss at step 6100: 0.429048
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 6150: 0.458541
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 6200: 0.459462
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 6250: 0.272607
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.0%
# Minibatch loss at step 6300: 0.385201
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 6350: 0.386886
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 6400: 0.396151
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.1%
# Minibatch loss at step 6450: 0.335986
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.0%
# Minibatch loss at step 6500: 0.389396
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 6550: 0.454204
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.1%
# Minibatch loss at step 6600: 0.305840
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 6650: 0.347463
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.2%
# Minibatch loss at step 6700: 0.393517
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 6750: 0.373687
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.3%
# Minibatch loss at step 6800: 0.351586
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.0%
# Minibatch loss at step 6850: 0.411108
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.1%
# Minibatch loss at step 6900: 0.420024
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 6950: 0.328612
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 7000: 0.418009
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.1%
# Minibatch loss at step 7050: 0.349265
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 7100: 0.434207
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 7150: 0.288178
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 7200: 0.393192
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 7250: 0.246158
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 7300: 0.596980
# Minibatch accuracy: 83.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 7350: 0.483224
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 7400: 0.504981
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 7450: 0.379510
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 7500: 0.374241
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 7550: 0.673727
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 7600: 0.325307
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 7650: 0.279979
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 7700: 0.417569
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 7750: 0.391792
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 7800: 0.518978
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.3%
# Minibatch loss at step 7850: 0.451978
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 7900: 0.528969
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 7950: 0.295567
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.4%
# Minibatch loss at step 8000: 0.280449
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 8050: 0.534812
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 8100: 0.392708
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.4%
# Minibatch loss at step 8150: 0.325974
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# Minibatch loss at step 8200: 0.351955
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.4%
# Minibatch loss at step 8250: 0.349672
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 8300: 0.414846
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 8350: 0.274696
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.3%
# Minibatch loss at step 8400: 0.381080
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.3%
# Minibatch loss at step 8450: 0.412306
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 8500: 0.403918
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.2%
# Minibatch loss at step 8550: 0.436779
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.3%
# Minibatch loss at step 8600: 0.314052
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 8650: 0.332362
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.5%
# Minibatch loss at step 8700: 0.356422
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 8750: 0.214304
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 8800: 0.293357
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 8850: 0.389000
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 8900: 0.436836
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 8950: 0.347950
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.5%
# Minibatch loss at step 9000: 0.397933
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.6%
# Minibatch loss at step 9050: 0.459718
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 9100: 0.329313
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 9150: 0.443792
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.4%
# Minibatch loss at step 9200: 0.568472
# Minibatch accuracy: 80.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 9250: 0.303199
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.5%
# Minibatch loss at step 9300: 0.281414
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 9350: 0.388501
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 9400: 0.372469
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.5%
# Minibatch loss at step 9450: 0.292580
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 9500: 0.372022
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 9550: 0.356149
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 9600: 0.299197
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 9650: 0.544011
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 9700: 0.479304
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.6%
# Minibatch loss at step 9750: 0.375352
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.8%
# Minibatch loss at step 9800: 0.215862
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 9850: 0.493393
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.8%
# Minibatch loss at step 9900: 0.483771
# Minibatch accuracy: 82.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 9950: 0.486877
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.8%
# Minibatch loss at step 10000: 0.391374
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 10050: 0.360555
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.5%
# Minibatch loss at step 10100: 0.308142
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 10150: 0.334124
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 10200: 0.335168
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.8%
# Minibatch loss at step 10250: 0.315626
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# Minibatch loss at step 10300: 0.538127
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 10350: 0.485037
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 10400: 0.476672
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 10450: 0.324035
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 10500: 0.247780
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 10550: 0.300811
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 10600: 0.254781
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 10650: 0.236272
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 10700: 0.297242
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 10750: 0.249005
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 10800: 0.433956
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.8%
# Minibatch loss at step 10850: 0.297932
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.7%
# Minibatch loss at step 10900: 0.274852
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.8%
# Minibatch loss at step 10950: 0.484269
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.9%
# Minibatch loss at step 11000: 0.393104
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 11050: 0.352960
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 11100: 0.502619
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 11150: 0.335605
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 11200: 0.378873
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 11250: 0.334833
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# Minibatch loss at step 11300: 0.333989
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 11350: 0.296905
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 11400: 0.341157
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# Minibatch loss at step 11450: 0.344802
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 11500: 0.487459
# Minibatch accuracy: 83.6%
# Validation accuracy: 90.1%
# Minibatch loss at step 11550: 0.312937
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# Minibatch loss at step 11600: 0.509297
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 11650: 0.360556
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 11700: 0.206958
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 11750: 0.309256
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 11800: 0.324926
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 11850: 0.402928
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.0%
# Minibatch loss at step 11900: 0.370154
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 11950: 0.432346
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.0%
# Minibatch loss at step 12000: 0.252795
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 12050: 0.592249
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 12100: 0.560362
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.0%
# Minibatch loss at step 12150: 0.457752
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.0%
# Minibatch loss at step 12200: 0.456617
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 12250: 0.420613
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.1%
# Minibatch loss at step 12300: 0.310514
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 12350: 0.399965
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 12400: 0.261979
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 12450: 0.314555
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.9%
# Minibatch loss at step 12500: 0.413892
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.1%
# Minibatch loss at step 12550: 0.309858
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 12600: 0.237230
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 12650: 0.328282
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.2%
# Minibatch loss at step 12700: 0.262246
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 12750: 0.322721
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 12800: 0.281432
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 12850: 0.415731
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 12900: 0.307967
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 12950: 0.372262
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 13000: 0.393468
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 13050: 0.313425
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 13100: 0.307398
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.3%
# Minibatch loss at step 13150: 0.207612
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 13200: 0.292244
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.1%
# Minibatch loss at step 13250: 0.278028
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
# Minibatch loss at step 13300: 0.365390
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 13350: 0.428605
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.3%
# Minibatch loss at step 13400: 0.355996
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 13450: 0.319173
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 13500: 0.410141
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 13550: 0.266573
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 13600: 0.308282
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.3%
# Minibatch loss at step 13650: 0.406469
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 13700: 0.315803
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 13750: 0.235916
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 13800: 0.443592
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 13850: 0.351700
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 13900: 0.332235
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 13950: 0.374155
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 14000: 0.395194
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 14050: 0.373262
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 14100: 0.225732
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 14150: 0.375140
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.3%
# Minibatch loss at step 14200: 0.374140
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 14250: 0.406109
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 14300: 0.370036
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 14350: 0.585943
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 14400: 0.345775
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.3%
# Minibatch loss at step 14450: 0.403203
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.3%
# Minibatch loss at step 14500: 0.431802
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 14550: 0.443142
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 14600: 0.316195
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 14650: 0.325151
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 14700: 0.332199
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 14750: 0.368161
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.3%
# Minibatch loss at step 14800: 0.329566
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 14850: 0.340679
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 14900: 0.312885
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 14950: 0.367197
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 15000: 0.395700
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 15050: 0.469074
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 15100: 0.427008
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 15150: 0.243528
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 15200: 0.305544
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 15250: 0.386977
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 15300: 0.259336
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 15350: 0.247686
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 15400: 0.228256
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 15450: 0.203477
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 15500: 0.376670
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 15550: 0.269092
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 15600: 0.365554
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 15650: 0.256672
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 15700: 0.374348
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 15750: 0.260245
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 15800: 0.297520
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 15850: 0.266597
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.3%
# Minibatch loss at step 15900: 0.321200
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 15950: 0.271651
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.4%
# Minibatch loss at step 16000: 0.277056
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 16050: 0.248199
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 16100: 0.267337
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.7%
# Minibatch loss at step 16150: 0.494442
# Minibatch accuracy: 83.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 16200: 0.176430
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 16250: 0.438366
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 16300: 0.255510
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 16350: 0.474289
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 16400: 0.295719
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 16450: 0.280733
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 16500: 0.362059
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 16550: 0.329140
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 16600: 0.216325
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 16650: 0.299719
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 16700: 0.450067
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 16750: 0.260937
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 16800: 0.394776
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 16850: 0.376893
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 16900: 0.376714
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 16950: 0.341408
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 17000: 0.268391
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 17050: 0.139760
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 17100: 0.378354
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 17150: 0.396608
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 17200: 0.515963
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 17250: 0.562923
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 17300: 0.264785
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 17350: 0.368738
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 17400: 0.302675
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# Minibatch loss at step 17450: 0.338249
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 17500: 0.532793
# Minibatch accuracy: 83.6%
# Validation accuracy: 90.6%
# Minibatch loss at step 17550: 0.293752
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.7%
# Minibatch loss at step 17600: 0.199405
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 17650: 0.370638
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 17700: 0.219755
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 17750: 0.357613
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 17800: 0.296151
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 17850: 0.412819
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.6%
# Minibatch loss at step 17900: 0.175284
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 17950: 0.251432
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 18000: 0.498715
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 18050: 0.314370
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 18100: 0.281492
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 18150: 0.391289
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 18200: 0.402073
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 18250: 0.294698
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 18300: 0.291205
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 18350: 0.253663
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 18400: 0.314426
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# Minibatch loss at step 18450: 0.210049
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 18500: 0.246640
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 18550: 0.354527
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 18600: 0.485580
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.7%
# Minibatch loss at step 18650: 0.283934
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 18700: 0.350527
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.8%
# Minibatch loss at step 18750: 0.249155
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 18800: 0.320497
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.9%
# Minibatch loss at step 18850: 0.289176
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.8%
# Minibatch loss at step 18900: 0.246627
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 18950: 0.301099
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 19000: 0.244643
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 19050: 0.234430
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 19100: 0.376994
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.8%
# Minibatch loss at step 19150: 0.281138
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 19200: 0.265979
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 19250: 0.404690
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.7%
# Minibatch loss at step 19300: 0.443132
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.7%
# Minibatch loss at step 19350: 0.391603
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 19400: 0.310422
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.8%
# Minibatch loss at step 19450: 0.290383
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 19500: 0.329030
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 19550: 0.332501
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# Minibatch loss at step 19600: 0.403147
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.7%
# Minibatch loss at step 19650: 0.338573
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.7%
# Minibatch loss at step 19700: 0.317663
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 19750: 0.320051
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 19800: 0.410882
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.8%
# Minibatch loss at step 19850: 0.366546
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 19900: 0.337595
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.6%
# Minibatch loss at step 19950: 0.329058
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 20000: 0.220279
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 20050: 0.292050
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 20100: 0.294172
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 20150: 0.354765
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.8%
# Minibatch loss at step 20200: 0.386764
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.8%
# Minibatch loss at step 20250: 0.302560
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 20300: 0.334627
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.7%
# Minibatch loss at step 20350: 0.298595
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# Minibatch loss at step 20400: 0.354778
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 20450: 0.308034
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# Minibatch loss at step 20500: 0.332419
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.7%
# Minibatch loss at step 20550: 0.266794
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# Minibatch loss at step 20600: 0.330890
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 20650: 0.322206
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 20700: 0.345283
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.0%
# Minibatch loss at step 20750: 0.300958
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.9%
# Minibatch loss at step 20800: 0.296901
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 20850: 0.225630
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 20900: 0.224414
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 20950: 0.387309
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 21000: 0.290093
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.7%
# Minibatch loss at step 21050: 0.353081
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.6%
# Minibatch loss at step 21100: 0.276607
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 21150: 0.328296
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# Minibatch loss at step 21200: 0.258792
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 21250: 0.414145
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.0%
# Minibatch loss at step 21300: 0.208759
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 21350: 0.250515
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 21400: 0.311566
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.6%
# Minibatch loss at step 21450: 0.220041
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 21500: 0.349155
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 21550: 0.339520
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.9%
# Minibatch loss at step 21600: 0.319172
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 21650: 0.457554
# Minibatch accuracy: 83.6%
# Validation accuracy: 90.8%
# Minibatch loss at step 21700: 0.200983
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 21750: 0.203105
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 21800: 0.316501
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.9%
# Minibatch loss at step 21850: 0.284568
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.9%
# Minibatch loss at step 21900: 0.162732
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 21950: 0.398254
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.0%
# Minibatch loss at step 22000: 0.141776
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.9%
# Minibatch loss at step 22050: 0.317785
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 22100: 0.253920
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# Minibatch loss at step 22150: 0.328703
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.9%
# Minibatch loss at step 22200: 0.255072
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.9%
# Minibatch loss at step 22250: 0.342390
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.9%
# Minibatch loss at step 22300: 0.239888
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.9%
# Minibatch loss at step 22350: 0.306093
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.0%
# Minibatch loss at step 22400: 0.250945
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# Minibatch loss at step 22450: 0.305083
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 22500: 0.295568
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# Minibatch loss at step 22550: 0.253950
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 22600: 0.565757
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.8%
# Minibatch loss at step 22650: 0.394907
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.8%
# Minibatch loss at step 22700: 0.412363
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.0%
# Minibatch loss at step 22750: 0.100234
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.9%
# Minibatch loss at step 22800: 0.265901
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.9%
# Minibatch loss at step 22850: 0.271717
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 22900: 0.292375
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.9%
# Minibatch loss at step 22950: 0.476995
# Minibatch accuracy: 83.6%
# Validation accuracy: 90.9%
# Minibatch loss at step 23000: 0.231410
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.9%
# Minibatch loss at step 23050: 0.313255
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.0%
# Minibatch loss at step 23100: 0.284837
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.0%
# Minibatch loss at step 23150: 0.318151
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.0%
# Minibatch loss at step 23200: 0.237781
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 23250: 0.336861
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.8%
# Minibatch loss at step 23300: 0.275535
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.9%
# Minibatch loss at step 23350: 0.142208
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.1%
# Minibatch loss at step 23400: 0.253281
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.9%
# Minibatch loss at step 23450: 0.303641
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 23500: 0.411536
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.0%
# Minibatch loss at step 23550: 0.311190
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 23600: 0.300559
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 23650: 0.303913
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.0%
# Minibatch loss at step 23700: 0.261786
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 23750: 0.330493
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 23800: 0.327270
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 23850: 0.356236
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.0%
# Minibatch loss at step 23900: 0.268361
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# Minibatch loss at step 23950: 0.329703
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 24000: 0.418132
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.1%
# Minibatch loss at step 24050: 0.263895
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 24100: 0.410378
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.8%
# Minibatch loss at step 24150: 0.389749
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.9%
# Minibatch loss at step 24200: 0.249943
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.9%
# Minibatch loss at step 24250: 0.388101
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.0%
# Minibatch loss at step 24300: 0.215392
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.8%
# Minibatch loss at step 24350: 0.308652
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 24400: 0.234313
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# Minibatch loss at step 24450: 0.230489
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 24500: 0.336986
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.9%
# Minibatch loss at step 24550: 0.524221
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.0%
# Minibatch loss at step 24600: 0.323215
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.9%
# Minibatch loss at step 24650: 0.321673
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.8%
# Minibatch loss at step 24700: 0.257252
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.9%
# Minibatch loss at step 24750: 0.191014
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.8%
# Minibatch loss at step 24800: 0.335600
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.0%
# Minibatch loss at step 24850: 0.319239
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.8%
# Minibatch loss at step 24900: 0.291759
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.0%
# Minibatch loss at step 24950: 0.243335
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.0%
# Minibatch loss at step 25000: 0.349465
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 25050: 0.260034
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# Minibatch loss at step 25100: 0.428564
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 25150: 0.283563
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.9%
# Minibatch loss at step 25200: 0.223808
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 25250: 0.420506
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.1%
# Minibatch loss at step 25300: 0.189600
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.2%
# Minibatch loss at step 25350: 0.245567
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.0%
# Minibatch loss at step 25400: 0.335048
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# Minibatch loss at step 25450: 0.210727
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.0%
# Minibatch loss at step 25500: 0.255941
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 25550: 0.454632
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.0%
# Minibatch loss at step 25600: 0.331269
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.0%
# Minibatch loss at step 25650: 0.357003
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 25700: 0.423331
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.9%
# Minibatch loss at step 25750: 0.344742
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.0%
# Minibatch loss at step 25800: 0.294674
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.1%
# Minibatch loss at step 25850: 0.393102
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.2%
# Minibatch loss at step 25900: 0.211558
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 25950: 0.301985
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.1%
# Minibatch loss at step 26000: 0.301920
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 26050: 0.480378
# Minibatch accuracy: 84.4%
# Validation accuracy: 91.0%
# Minibatch loss at step 26100: 0.393860
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.1%
# Minibatch loss at step 26150: 0.254755
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# ...
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.4%
# Minibatch loss at step 41400: 0.278469
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 41450: 0.364465
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 41500: 0.345020
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 41550: 0.334142
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.4%
# Minibatch loss at step 41600: 0.261374
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.3%
# Minibatch loss at step 41650: 0.254200
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.4%
# Minibatch loss at step 41700: 0.296672
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.4%
# Minibatch loss at step 41750: 0.145936
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.4%
# Minibatch loss at step 41800: 0.236381
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 41850: 0.144450
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 41900: 0.239994
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 41950: 0.535959
# Minibatch accuracy: 82.0%
# Validation accuracy: 91.4%
# Minibatch loss at step 42000: 0.195107
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 42050: 0.189238
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 42100: 0.254402
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.5%
# Minibatch loss at step 42150: 0.213620
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.4%
# Minibatch loss at step 42200: 0.171084
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 42250: 0.246979
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 42300: 0.166768
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 42350: 0.432265
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.5%
# Minibatch loss at step 42400: 0.328760
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.5%
# Minibatch loss at step 42450: 0.283864
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 42500: 0.253846
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 42550: 0.318552
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 42600: 0.178697
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 42650: 0.265625
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 42700: 0.327791
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.4%
# Minibatch loss at step 42750: 0.452706
# Minibatch accuracy: 84.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 42800: 0.284429
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 42850: 0.217064
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.3%
# Minibatch loss at step 42900: 0.330674
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 42950: 0.322962
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 43000: 0.294879
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 43050: 0.160347
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 43100: 0.231497
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 43150: 0.187270
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 43200: 0.265990
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 43250: 0.363533
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 43300: 0.226091
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 43350: 0.249457
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.4%
# Minibatch loss at step 43400: 0.187132
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 43450: 0.287395
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 43500: 0.196798
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.4%
# Minibatch loss at step 43550: 0.141321
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 43600: 0.200791
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.4%
# Minibatch loss at step 43650: 0.147139
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 43700: 0.240488
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.5%
# Minibatch loss at step 43750: 0.343771
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.5%
# Minibatch loss at step 43800: 0.334720
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 43850: 0.291718
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.4%
# Minibatch loss at step 43900: 0.375608
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.4%
# Minibatch loss at step 43950: 0.360001
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 44000: 0.170568
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 44050: 0.289553
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 44100: 0.252069
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 44150: 0.219614
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 44200: 0.173544
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 44250: 0.443082
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 44300: 0.387667
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 44350: 0.137726
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 44400: 0.333960
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.3%
# Minibatch loss at step 44450: 0.348701
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.5%
# Minibatch loss at step 44500: 0.292566
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 44550: 0.373106
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 44600: 0.167055
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 44650: 0.316088
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 44700: 0.275113
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 44750: 0.322467
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 44800: 0.160781
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.5%
# Minibatch loss at step 44850: 0.313611
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 44900: 0.265016
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.8%
# Minibatch loss at step 44950: 0.199262
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 45000: 0.353279
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 45050: 0.193068
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 45100: 0.250172
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 45150: 0.304268
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 45200: 0.367090
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 45250: 0.257278
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.2%
# Minibatch loss at step 45300: 0.271998
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 45350: 0.301067
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 45400: 0.264339
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 45450: 0.258019
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.4%
# Minibatch loss at step 45500: 0.195026
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 45550: 0.381711
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 45600: 0.185485
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 45650: 0.221869
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 45700: 0.394422
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 45750: 0.176558
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 45800: 0.187795
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 45850: 0.237004
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 45900: 0.305164
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.5%
# Minibatch loss at step 45950: 0.272733
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.5%
# Minibatch loss at step 46000: 0.342460
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.6%
# Minibatch loss at step 46050: 0.358332
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 46100: 0.286150
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 46150: 0.248026
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 46200: 0.236685
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 46250: 0.220952
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 46300: 0.378230
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 46350: 0.360197
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 46400: 0.284193
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 46450: 0.201522
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 46500: 0.279309
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 46550: 0.208198
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 46600: 0.245888
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 46650: 0.307007
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 46700: 0.274916
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 46750: 0.195706
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 46800: 0.376347
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 46850: 0.296856
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 46900: 0.255476
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 46950: 0.198812
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 47000: 0.421504
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.6%
# Minibatch loss at step 47050: 0.252141
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 47100: 0.275547
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 47150: 0.408142
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 47200: 0.273076
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 47250: 0.237829
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 47300: 0.373039
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 47350: 0.345019
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.4%
# Minibatch loss at step 47400: 0.256017
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 47450: 0.322214
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 47500: 0.187729
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 47550: 0.241219
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 47600: 0.212795
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 47650: 0.353667
# Minibatch accuracy: 85.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 47700: 0.271167
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.7%
# Minibatch loss at step 47750: 0.172679
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 47800: 0.229310
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 47850: 0.422588
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 47900: 0.355842
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 47950: 0.284311
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.3%
# Minibatch loss at step 48000: 0.305005
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 48050: 0.297919
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 48100: 0.265646
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 48150: 0.278606
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 48200: 0.363729
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.5%
# Minibatch loss at step 48250: 0.203812
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 48300: 0.304377
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 48350: 0.277858
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 48400: 0.224772
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 48450: 0.270852
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.8%
# Minibatch loss at step 48500: 0.317139
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 48550: 0.173541
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 48600: 0.326048
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 48650: 0.250256
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.5%
# Minibatch loss at step 48700: 0.229263
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 48750: 0.110492
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 48800: 0.214563
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 48850: 0.146545
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 48900: 0.220973
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 48950: 0.182126
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 49000: 0.176717
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 49050: 0.236658
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 49100: 0.299219
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 49150: 0.262695
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 49200: 0.205128
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 49250: 0.291294
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 49300: 0.267679
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 49350: 0.333732
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 49400: 0.216838
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 49450: 0.290048
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 49500: 0.255657
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 49550: 0.322322
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 49600: 0.246390
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 49650: 0.334323
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 49700: 0.352946
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.8%
# Minibatch loss at step 49750: 0.151307
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 49800: 0.190396
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 49850: 0.238076
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 49900: 0.228999
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 49950: 0.238643
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 50000: 0.296088
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Test accuracy: 96.2%
